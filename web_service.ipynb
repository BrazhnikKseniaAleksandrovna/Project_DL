# %%
# %pip install torch torchaudio librosa tqdm streamlit
# %pip install pyngrok
# %pip install streamlit
# %pip install pydub
# Out:
# Requirement already satisfied: torch in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (2.3.0)
# Requirement already satisfied: torchaudio in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (2.3.0)
# Requirement already satisfied: librosa in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (0.11.0)
# Requirement already satisfied: tqdm in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (4.67.1)
# Requirement already satisfied: streamlit in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (1.35.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: sympy in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: filelock in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.18.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from torch) (2021.4.0)
# Requirement already satisfied: jinja2 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from torch) (2025.5.0)
# Requirement already satisfied: numba>=0.51.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from librosa) (0.61.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from librosa) (5.2.1)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: scikit-learn>=1.1.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.6.1)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.26.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.1.0)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from librosa) (0.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.15.3)
# Requirement already satisfied: pooch>=1.1 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.8.2)
# Requirement already satisfied: joblib>=1.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.5.1)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: colorama in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (3.1.44)
# Requirement already satisfied: click<9,>=7.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (8.2.1)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (4.25.7)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (20.0.0)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (8.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (5.5.2)
# Requirement already satisfied: packaging<25,>=16.8 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (10.4.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (13.9.4)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from altair<6,>=4.0->streamlit) (1.40.0)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.25.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.13.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from numba>=0.51.0->librosa) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2025.2)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from pooch>=1.1->librosa) (4.3.8)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: six>=1.5 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.17.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.4.26)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.27->streamlit) (2.4.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from soundfile>=0.12.1->librosa) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from sympy->torch) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.1.1 is available.
# You should consider upgrading via the 'c:\Users\Valee\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: pyngrok in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (7.2.8)
# Requirement already satisfied: PyYAML>=5.1 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from pyngrok) (6.0.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.1.1 is available.
# You should consider upgrading via the 'c:\Users\Valee\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: streamlit in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (1.35.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: packaging<25,>=16.8 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (4.25.7)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (4.13.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (5.5.2)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (20.0.0)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: click<9,>=7.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (8.2.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (13.9.4)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (8.5.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (10.4.0)
# Requirement already satisfied: jinja2 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from altair<6,>=4.0->streamlit) (1.40.0)
# Requirement already satisfied: colorama in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.25.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2025.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: six>=1.5 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.17.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.4.26)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.27->streamlit) (2.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.1.1 is available.
# You should consider upgrading via the 'c:\Users\Valee\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: pydub in c:\users\valee\appdata\local\programs\python\python310\lib\site-packages (0.25.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.1.1 is available.
# You should consider upgrading via the 'c:\Users\Valee\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
NGROK_AUTH_TOKEN = "2xbHIV9rr6inomVfrSF18HpUlm4_849oeTTzSzf9cdDDd9BQR"

# %%
# %%writefile app.py
import streamlit as st
import torch
import torchaudio
import torchaudio.transforms as T
import torch.nn as nn
import pickle
import io
import numpy as np
import tempfile
from pydub import AudioSegment

st.set_page_config(page_title="Голосовые команды", layout="centered")
st.title("🎤 Распознавание голосовых команд из файла")

SAMPLE_CLASSES_WITH_UNKNOWN = ['yes', 'no', 'up', 'down', 'left', 'right',
                             'on', 'off', 'stop', 'go']


class SpeechCommandModel(nn.Module):
    def __init__(self, num_classes=10):  # 10 классов по умолчанию
        super().__init__()
        # CNN блок для извлечения признаков
        self.cnn = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1),  # [B, 16, 64, T]
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(2),  # [B, 16, 32, T//2]

            nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1),  # [B, 32, 32, T//2]
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2),  # [B, 32, 16, T//4]

            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),  # [B, 64, 16, T//4]
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2),  # [B, 64, 8, T//8]
        )

        # Глобальный средний пулинг
        self.gap = nn.AdaptiveAvgPool2d((1, 1))  # [B, 64, 1, 1]

        # Полносвязный классификатор
        self.fc = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        # Входной тензор уже должен быть формы [B, 1, 64, T]
        x = self.cnn(x)
        x = self.gap(x)
        x = self.fc(x)
        return x

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SpeechCommandModel(num_classes=len(SAMPLE_CLASSES_WITH_UNKNOWN)).to(device)
model.load_state_dict(torch.load("speech_command_cnn.pth", map_location=device))
model.eval()

# Загрузка словаря меток
with open("label2idx.pkl", "rb") as f:
    label2idx = pickle.load(f)
idx2label = {v: k for k, v in label2idx.items()}

st.markdown("""
#### Инструкция:
1. Запишите команду через [online-voice-recorder.com/ru](https://online-voice-recorder.com/ru) или любое другое средство
2. Сохраните как .wav или .mp3 файл
3. Загрузите его ниже — система сама приведёт формат к нужному
""")

uploaded_file = st.file_uploader("Загрузите аудиофайл (wav/mp3)", type=["wav", "mp3"])
if uploaded_file is not None:
    st.audio(uploaded_file)

    try:
        # Сохраняем во временный файл
        with tempfile.NamedTemporaryFile(delete=False, suffix=".wav") as tmp_wav:
            if uploaded_file.name.endswith(".mp3"):
                sound = AudioSegment.from_file(uploaded_file, format="mp3")
                sound = sound.set_frame_rate(16000).set_channels(1)
                sound.export(tmp_wav.name, format="wav")
            else:
                tmp_wav.write(uploaded_file.read())

            waveform, sr = torchaudio.load(tmp_wav.name)

        # Моно
        if waveform.shape[0] > 1:
            waveform = waveform.mean(dim=0, keepdim=True)

        # Приведение к 16 кГц
        if sr != 16000:
            resampler = T.Resample(sr, 16000)
            waveform = resampler(waveform)
            sr = 16000

        # Приведение к 1 секунде
        if waveform.shape[1] < 16000:
            pad_len = 16000 - waveform.shape[1]
            waveform = torch.nn.functional.pad(waveform, (0, pad_len))
        else:
            waveform = waveform[:, :16000]

        # Спектрограмма
        mel = T.MelSpectrogram(sr, n_mels=64)(waveform)
        mel = T.AmplitudeToDB()(mel)
        mel = mel.unsqueeze(0)
        mel = torch.nn.functional.pad(mel, (0, max(0, 128 - mel.shape[-1])))
        mel = mel[:, :, :, :128]

        # Предсказание
        out = model(mel)
        pred = out.argmax(dim=1).item()
        command = idx2label.get(pred, "Неизвестно")

        st.success(f"✅ Распознанная команда: **{command}**")

    except Exception as e:
        st.error(f"❌ Ошибка при обработке: {e}")
# Out:
# Overwriting app.py

# %%
from pyngrok import ngrok

# Авторизация ngrok
ngrok.set_auth_token(NGROK_AUTH_TOKEN)

# Проброс порта 8501 для Streamlit
public_url = ngrok.connect(8501)
print('Streamlit URL:', public_url)

# %%
# Запуск Streamlit (это важно делать с !)
# !streamlit run app.py
